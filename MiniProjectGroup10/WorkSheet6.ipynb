# %% [markdown]
# Worksheet6

# %% [markdown]
# importing panda library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading in data file

# %%
data = pd.read_csv('https://raw.githubusercontent.com/bdishionn/cs131/master/MiniProjectGroup10/Fortune%201000%20Companies%20by%20Revenue.csv')

# %% [markdown]
# 1. Head

# %%
data.head()
# Out:
#   rank                name   revenues  revenue_percent_change  profits   \
# 0     1             Walmart  $572,754                   2.40%  $13,673
# 1     2              Amazon  $469,822                  21.70%  $33,364
# 2     3               Apple  $365,817                  33.30%  $94,680
# 3     4          CVS Health  $292,111                   8.70%   $7,910
# 4     5  UnitedHealth Group  $287,597                  11.80%  $17,285
#
#   profits_percent_change     assets   market_value  change_in_rank employees
# 0                  1.20%  $244,860        $409,795               -  2,300,000
# 1                 56.40%  $420,549   $1,658,807.30               -  1,608,000
# 2                 64.90%  $351,002   $2,849,537.60               -    154,000
# 3                 10.20%  $232,999     $132,839.20               -    258,000
# 4                 12.20%  $212,206     $479,830.30               -    350,000

# %% [markdown]
# 1. Tail

# %%
data.tail()
# Out:
#      rank                     name    revenues  revenue_percent_change  \
# 995    996            Vizio Holding     $2,124                      4%
# 996    997        1-800-Flowers.com  $2,122.20                  42.50%
# 997    998                    Cowen  $2,112.80                  30.20%
# 998    999  Ashland Global Holdings     $2,111                 -11.20%
# 999  1,000                 DocuSign  $2,107.20                     45%
#
#      profits  profits_percent_change      assets market_value  change_in_rank  \
# 995  ($39.40)               -138.40%    $935.80     $1,705.10               -
# 996  $118.70                 101.10%  $1,076.70          $830               -
# 997  $295.60                  36.60%  $8,748.80       $744.10               -
# 998     $220                       -     $6,612     $5,601.90            -130
# 999     ($70)                      -  $2,541.30    $21,302.80               -
#
#     employees
# 995        800
# 996      4,800
# 997      1,534
# ...

# %% [markdown]
# 2. DataFrame.info() - concise summary of dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   rank                    1000 non-null   object
#  1   name                    1000 non-null   object
#  2   revenues                1000 non-null   object
#  3   revenue_percent_change  1000 non-null   object
#  4   profits                 1000 non-null   object
#  5   profits_percent_change  1000 non-null   object
#  6   assets                  1000 non-null   object
#  7   market_value            1000 non-null   object
#  8   change_in_rank          1000 non-null   object
#  9   employees               1000 non-null   object
# dtypes: object(10)
# memory usage: 78.2+ KB

# %% [markdown]
# 3. Dtypes - shows the data type of each column

# %%
data.dtypes
# Out:
# rank                      object
# name                      object
# revenues                  object
# revenue_percent_change    object
# profits                   object
# profits_percent_change    object
# assets                    object
# market_value              object
# change_in_rank            object
# employees                 object
# dtype: object

# %% [markdown]
# 4. Shape

# %%
data.shape
# Out:
# (1000, 10)

# %% [markdown]
# 4. Size

# %%
data.size
# Out:
# 10000

# %% [markdown]
# 5. describe() - statistical summary for every numerical column

# %%
data.describe()
# Out:
#        rank     name  revenues  revenue_percent_change profits   \
# count   1000     1000      1000                   1000     1000
# unique   997     1000       993                    556      965
# top      466  Walmart   $7,156                       -        -
# freq       2        1         2                      8        3
#
#        profits_percent_change    assets market_value  change_in_rank  \
# count                    1000      1000          1000           1000
# unique                    641       997           956            276
# top                         -  $13,223              -              -
# freq                      273         2            45             80
#
#        employees
# count        1000
# unique        763
# top        14,000
# freq            8

# %% [markdown]
# 5. describe() - statistical summary for every numerical row

# %%
data.describe(include='all').T
# Out:
#                        count unique       top freq
# rank                    1000    997       466    2
# name                    1000   1000   Walmart    1
# revenues                1000    993   $7,156     2
# revenue_percent_change  1000    556         -    8
# profits                 1000    965         -    3
# profits_percent_change  1000    641         -  273
# assets                  1000    997  $13,223     2
# market_value            1000    956         -   45
# change_in_rank          1000    276         -   80
# employees               1000    763    14,000    8

# %% [markdown]
# 6. Sample - allows you to select randomly from dataframe

# %%
data.sample(n=8)
# Out:
#     rank                     name     revenues  revenue_percent_change  \
# 647   648                   Amerco      $4,542                  14.20%
# 638   639         Antero Resources   $4,619.40                  32.30%
# 416   417               S&P Global      $8,297                  11.50%
# 512   513  Select Medical Holdings   $6,204.50                  12.20%
# 195   196           Steel Dynamics  $18,408.90                  91.70%
# 891   892       Werner Enterprises   $2,734.40                  15.30%
# 4       5       UnitedHealth Group    $287,597                  11.80%
# 182   183                   Kohl's     $19,433                  21.80%
#
#        profits  profits_percent_change       assets market_value   \
# 647    $610.90                  38.20%  $14,651.60    $11,704.70
# 638   ($186.90)                      -  $13,896.50        $9,608
# 416     $3,024                  29.30%     $15,026   $142,343.50
# ...

# %% [markdown]
# 7. Identifying Missing Values Isnull

# %%
data.isnull()
# Out:
#      rank   name   revenues   revenue_percent_change  profits   \
# 0    False  False      False                   False     False
# 1    False  False      False                   False     False
# 2    False  False      False                   False     False
# 3    False  False      False                   False     False
# 4    False  False      False                   False     False
# ..     ...    ...        ...                     ...       ...
# 995  False  False      False                   False     False
# 996  False  False      False                   False     False
# 997  False  False      False                   False     False
# 998  False  False      False                   False     False
# 999  False  False      False                   False     False
#
#      profits_percent_change  assets  market_value   change_in_rank  employees
# 0                     False   False          False           False       False
# ...

# %% [markdown]
# 8. Isna - returns dataframe filled with bollean values with true indicating missing values

# %%
data.isna().any()
# Out:
# rank                      False
# name                      False
# revenues                  False
# revenue_percent_change    False
# profits                   False
# profits_percent_change    False
# assets                    False
# market_value              False
# change_in_rank            False
# employees                 False
# dtype: bool

# %% [markdown]
# 9. Identifying Missing Values Sum

# %%
data.isnull().sum()
# Out:
# rank                      0
# name                      0
# revenues                  0
# revenue_percent_change    0
# profits                   0
# profits_percent_change    0
# assets                    0
# market_value              0
# change_in_rank            0
# employees                 0
# dtype: int64

# %% [markdown]
# 10. Nunique - counts the # of entries over columns or rows

# %%
data.nunique()
# Out:
# rank                       997
# name                      1000
# revenues                   993
# revenue_percent_change     556
# profits                    965
# profits_percent_change     641
# assets                     997
# market_value               956
# change_in_rank             276
# employees                  763
# dtype: int64

# %% [markdown]
# 11. Index() -searches for a given element from the start and returns the lowest index where element appears in the list

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# 11. Column()

# %%
data.columns
# Out:
# Index(['rank ', 'name ', 'revenues ', 'revenue_percent_change', 'profits ',
#        'profits_percent_change', 'assets', 'market_value ', 'change_in_rank',
#        'employees '],
#       dtype='object')

# %% [markdown]
# 12. Memory Usage - returns how much memory each column uses in bytes

# %%
data.memory_usage()
# Out:
# Index                      128
# rank                      8000
# name                      8000
# revenues                  8000
# revenue_percent_change    8000
# profits                   8000
# profits_percent_change    8000
# assets                    8000
# market_value              8000
# change_in_rank            8000
# employees                 8000
# dtype: int64

# %% [markdown]
# 13. nsmallest()

# %%
data.nsmallest(5, 'profits')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-0bd824277924> in <cell line: 7>()
#       5
#       6 # Convert the cleaned 'market_value' column to numeric, coerce errors to NaN
# ----> 7 data['market_value'] = pd.to_numeric(data['market_value'], errors='coerce')
#       8
#       9 # Handle NaN values by filling them with zero or another appropriate value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     163         values = np.array([arg], dtype="O")
#     164     elif getattr(arg, "ndim", 1) > 1:
# --> 165         raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     166     else:
#     167         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %% [markdown]
# 13. nlargest()

# %%
data.nlargest(5, 'rank ')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rank '
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# 14. Loc - select by labels

# %%
data.loc[:5,['profits ','rank ']]
# Out:
#    profits  rank
# 0  $13,673      1
# 1  $33,364      2
# 2  $94,680      3
# 3   $7,910      4
# 4  $17,285      5
# 5  $23,040      6

# %% [markdown]
# 14. iloc - select by positions

# %%
data.iloc[:4,:6]
# Out:
#   rank        name   revenues  revenue_percent_change  profits   \
# 0     1     Walmart  $572,754                   2.40%  $13,673
# 1     2      Amazon  $469,822                  21.70%  $33,364
# 2     3       Apple  $365,817                  33.30%  $94,680
# 3     4  CVS Health  $292,111                   8.70%   $7,910
#
#   profits_percent_change
# 0                  1.20%
# 1                 56.40%
# 2                 64.90%
# 3                 10.20%

# %% [markdown]
# 15. Slicing

# %%
data[0:4]
# Out:
#   rank        name   revenues  revenue_percent_change  profits   \
# 0     1     Walmart  $572,754                   2.40%  $13,673
# 1     2      Amazon  $469,822                  21.70%  $33,364
# 2     3       Apple  $365,817                  33.30%  $94,680
# 3     4  CVS Health  $292,111                   8.70%   $7,910
#
#   profits_percent_change     assets   market_value  change_in_rank employees
# 0                  1.20%  $244,860        $409,795               -  2,300,000
# 1                 56.40%  $420,549   $1,658,807.30               -  1,608,000
# 2                 64.90%  $351,002   $2,849,537.60               -    154,000
# 3                 10.20%  $232,999     $132,839.20               -    258,000

# %% [markdown]
# 16. Groupby - toll for exploring data

# %%
data[['rank ', 'assets', 'revenues ']].groupby(['rank ', 'assets']).mean()
# Out:
# <ipython-input-24-a2d8fa3e0061>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data[['rank ', 'assets', 'revenues ']].groupby(['rank ', 'assets']).mean()
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# 17. Sorting

# %%
data.sort_index(axis=1,ascending=True)
# Out:
#          assets change_in_rank employees    market_value   \
# 0     $244,860               -  2,300,000       $409,795
# 1     $420,549               -  1,608,000  $1,658,807.30
# 2     $351,002               -    154,000  $2,849,537.60
# 3     $232,999               -    258,000    $132,839.20
# 4     $212,206               -    350,000    $479,830.30
# ..          ...            ...        ...             ...
# 995    $935.80               -        800      $1,705.10
# 996  $1,076.70               -      4,800           $830
# 997  $8,748.80               -      1,534        $744.10
# 998     $6,612            -130      4,100      $5,601.90
# 999  $2,541.30               -      7,461     $21,302.80
#
#                        name   profits  profits_percent_change  rank   \
# 0                    Walmart  $13,673                   1.20%      1
# 1                     Amazon  $33,364                  56.40%      2
# ...

# %% [markdown]
# 17. Sorting by values

# %%
data.sort_values(by='revenues ')
# Out:
#     rank                              name     revenues   \
# 354   355                        Altice USA  $10,090.80
# 353   354                      Weyerhaeuser     $10,201
# 352   353                 Interpublic Group  $10,240.70
# 351   352             Molson Coors Beverage  $10,279.70
# 350   351  Thrivent Financial for Lutherans  $10,312.70
# ..    ...                               ...          ...
# 355   356           Raymond James Financial      $9,910
# 36     37                 Johnson & Johnson     $93,775
# 35     36                   Bank of America     $93,851
# 34     35                            Lowe's     $96,250
# 33     34                               UPS     $97,287
#
#     revenue_percent_change    profits  profits_percent_change        assets  \
# 354                     2%    $990.30                    127%      $33,215
# 353                 35.40%     $2,607                 227.10%      $17,652
# ...

# %% [markdown]
# 18. Dropna

# %%
drop_cols = ['revenues ']
data.drop(drop_cols,axis=1,inplace=True)
data
# Out:
#      rank                     name  revenue_percent_change  profits   \
# 0        1                  Walmart                  2.40%  $13,673
# 1        2                   Amazon                 21.70%  $33,364
# 2        3                    Apple                 33.30%  $94,680
# 3        4               CVS Health                  8.70%   $7,910
# 4        5       UnitedHealth Group                 11.80%  $17,285
# ..     ...                      ...                    ...       ...
# 995    996            Vizio Holding                     4%  ($39.40)
# 996    997        1-800-Flowers.com                 42.50%  $118.70
# 997    998                    Cowen                 30.20%  $295.60
# 998    999  Ashland Global Holdings                -11.20%     $220
# 999  1,000                 DocuSign                    45%     ($70)
#
#     profits_percent_change      assets   market_value  change_in_rank  \
# 0                    1.20%   $244,860        $409,795               -
# ...

# %% [markdown]
# 19. Query

# %%
data.query('40000 < assets < 100000')[:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-cf21350d3ef6> in <cell line: 1>()
# ----> 1 data.query('40000 < assets < 100000')[:1]
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4472         kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473         kwargs["target"] = None
# -> 4474         res = self.eval(expr, **kwargs)
#    4475
#    4476         try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %% [markdown]
# 20. Insert

# %%
new_col=np.random.randn(1000)
data.insert (8,'new_col',new_col)
data.head()
# Out:
#   rank                name  revenue_percent_change  profits   \
# 0     1             Walmart                  2.40%  $13,673
# 1     2              Amazon                 21.70%  $33,364
# 2     3               Apple                 33.30%  $94,680
# 3     4          CVS Health                  8.70%   $7,910
# 4     5  UnitedHealth Group                 11.80%  $17,285
#
#   profits_percent_change     assets   market_value  change_in_rank   new_col  \
# 0                  1.20%  $244,860        $409,795               -  1.322857
# 1                 56.40%  $420,549   $1,658,807.30               -  1.925054
# 2                 64.90%  $351,002   $2,849,537.60               - -0.132304
# 3                 10.20%  $232,999     $132,839.20               -  0.825468
# 4                 12.20%  $212,206     $479,830.30               -  1.504542
#
#   employees
# 0  2,300,000
# 1  1,608,000
# 2    154,000
# 3    258,000
# 4    350,000
